# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_auc_score,roc_curve
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler,OneHotEncoder
from scipy.stats import zscore
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv")

# %%
ds.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
ds.shape
# Out:
# (16468, 14)

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
ds.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %%
ds.groupby('year')['AveragePrice'].mean()
ds
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
ds.type
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 16463             NaN
# 16464             NaN
# 16465             NaN
# 16466             NaN
# 16467             NaN
# Name: type, Length: 16468, dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %%
ds.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
sns.heatmap(ds.isnull().sum().to_frame())
# Out:
# <AxesSubplot:>

# %%
df=ds.drop(['type','year','Date'],axis=1)

# %%
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0             0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1             1.0          1.35      54876.98   674.28   44638.81   58.33
# 2             2.0          0.93     118220.22   794.70  109149.67  130.50
# 3             3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4             4.0          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16463         NaN           NaN           NaN      NaN        NaN     NaN
# 16464         NaN           NaN           NaN      NaN        NaN     NaN
# 16465         NaN           NaN           NaN      NaN        NaN     NaN
# 16466         NaN           NaN           NaN      NaN        NaN     NaN
# 16467         NaN           NaN           NaN      NaN        NaN     NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  region
# ...

# %%
y=df.iloc[:,1]
y
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 16463     NaN
# 16464     NaN
# 16465     NaN
# 16466     NaN
# 16467     NaN
# Name: AveragePrice, Length: 16468, dtype: float64

# %%
x=df.iloc[:,2:14]
x
# Out:
#        Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0          64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1          54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2         118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3          78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4          51039.60   941.48   43838.39   75.78     6183.95     5986.26
# ...             ...      ...        ...     ...         ...         ...
# 16463           NaN      NaN        NaN     NaN         NaN         NaN
# 16464           NaN      NaN        NaN     NaN         NaN         NaN
# 16465           NaN      NaN        NaN     NaN         NaN         NaN
# 16466           NaN      NaN        NaN     NaN         NaN         NaN
# 16467           NaN      NaN        NaN     NaN         NaN         NaN
#
#        Large Bags  XLarge Bags  region
# 0           93.25          0.0  Albany
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %%
x_train.shape
# Out:
# (12845, 9)

# %%
y_train.shape
# Out:
# (12845,)

# %%
x_test.shape
# Out:
# (3623, 9)

# %%
y_test.shape
# Out:
# (3623,)

# %%
le=LabelEncoder()

# %%
list=['region']
for val in list:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
model=LinearRegression()
max_r2_score=0
for r_state in range(40,90):
    
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=r_state)
    for i in range(40,90):
        i.fit(x_train , y_train)
        pre=i.predict(x_test)
        r2_sc=r2_score(y_test,pre)
        print("R2 score corrospondent to random state",r_state,"is",r2_sc)
        if r2_sc>max_r2_score:
            max_r2_score=r2_sc
            final_state=r_state
            final_model=i
print()
print()
print()
print("max R2 score",final_state,"is",max_r2_score,"and model is",final_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3452/918563170.py in <module>
#       6     for i in range(40,90):
#       7
# ----> 8         pre=i.predict(x_test)
#       9         r2_sc=r2_score(y_test,pre)
#      10         print("R2 score corrospondent to random state",r_state,"is",r2_sc)
#
# AttributeError: 'int' object has no attribute 'predict'

# %%
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=80)
    KN=KNeighborsRegressor
    parameters={'n_neighbors':range(1,30)}
    gridsearch=GridSearchCV(KN,parameters)
